# %%
from openai import OpenAI

client = OpenAI(
  base_url="https://openrouter.ai/api/v1",
  api_key="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",
)

completion = client.chat.completions.create(model="openai/gpt-4o",
messages=[
    {
      "role": "user",
      "content": "What is the meaning of life?"
    }
  ]
)

print(completion.choices[0].message.content)
# Out:
# The meaning of life is a profound philosophical question that has been contemplated by humans for centuries. Various perspectives include:
#
# 1. **Religious Viewpoints**: Many religions provide specific meanings based on divine purpose, spiritual development, or an afterlife. For instance, in Christianity, it might be about serving God and achieving eternal life; in Buddhism, it could involve the pursuit of enlightenment.
#
# 2. **Philosophical Approaches**: Philosophers offer diverse answers. Existentialists like Jean-Paul Sartre assert that life has no inherent meaning, and it’s up to individuals to create their own meaning. Others, like Aristotle, suggest that achieving eudaimonia (human flourishing) is the purpose of life.
#
# 3. **Scientific Perspective**: From a scientific viewpoint, life might be seen as a set of biological processes. Evolutionary biology suggests that life's purpose is to survive, reproduce, and pass on genes to subsequent generations.
#
# ...

# %%
import openai

openai.api_base = "https://openrouter.ai/api/v1"
openai.api_key = "not-needed"

headers = {
    "Authorization": "Bearer YOUR-OPENROUTER-KEY",
    "HTTP-Referer": "http://localhost",
    "X-Title": "test-script"
}

resp = openai.ChatCompletion.create(
    model="mistralai/mistral-7b-instruct",
    messages=[
        {"role": "user", "content": "Write a VMD Tcl command to color chain A red."}
    ],
    headers=headers
)

print(resp["choices"][0]["message"]["content"])
